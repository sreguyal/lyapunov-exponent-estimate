# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from LyapunovExponentEstimate import lyapunov_solve, lyapunov_solve_unknown, solve_roessler, solve_lorenz
# %matplotlib inline

# %%
t, x_t = solve_lorenz(max_time=500, step_size=0.01)
plt.plot(t, x_t)

x_t = x_t[2000:] #crop transient
fig = plt.figure(figsize=(15, 12))
ax = plt.axes(projection='3d')
ax.set_title('Numerical Solution to Lorenz Attractor')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.plot(x_t[:,0], x_t[:,1], x_t[:,2])
plt.show()

lorenz_t = x_t

# %%
t, x_t = solve_roessler(max_time=1000, step_size=0.01)
plt.plot(t, x_t)

x_t = x_t[1000:] #crop transient
fig = plt.figure(figsize=(15, 12))
ax = plt.axes(projection='3d')
ax.set_title('Numerical Solution to Roessler Attractor')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.plot(x_t[:,0], x_t[:,1], x_t[:,2])
plt.show()

roessler_t = x_t

# %%
# running this returns an inaccurate result
# because we haven't used finetuning or used many data points
# but it still finds that this is a chaotic system!
lyapunov_solve_unknown(lorenz_t, 0.01)
# Out:
# 100%|██████████| 21/21 [00:08<00:00,  2.48it/s]
# 0.07874836016857271

# %%
# this should give a more accurate estimation
lyapunov_solve(lorenz_t, 0.01, 0.5)
# Out:
# 100%|██████████| 958/958 [07:23<00:00,  2.16it/s]
# 1.4477038422715898

# %%
# that was still a bit off but better! it has been a while since I've touched this code, I've forgotten how I got that 2.20 experimental value. but you get the idea I hope...

# %%
lyapunov_solve(lorenz_t[int(lorenz_t.shape[0] *3/5) : ], 0.01, 0.5, plot_replace=True)
# Out:
# 100%|██████████| 382/382 [01:21<00:00,  4.68it/s]
# 1.4541502899573118
